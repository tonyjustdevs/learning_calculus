# %% [markdown]
# # Ex2-2-86
#
# ### $\lim_{x\to-1}\frac{x^3-x^2-5x-3}{(x+1)^2}$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.linspace(-1.1,-0.9,21)
xs
fx = lambda x: (x**3-x**2-5*x-3)/((x+1)**2)
ys = fx(xs)

plt.scatter(xs, ys)
# Out:
# /tmp/ipykernel_7129/4041640473.py:3: RuntimeWarning: invalid value encountered in divide
#   fx = lambda x: (x**3-x**2-5*x-3)/((x+1)**2)
