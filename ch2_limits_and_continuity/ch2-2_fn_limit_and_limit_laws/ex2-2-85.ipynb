# %% [markdown]
# # Ex2.3.85 #
#
# $ lim_{x\to2} \frac{x^4-16}{x-2}$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.linspace(2.1,1.9,21)
fx = lambda x: (x**4-16)/(x-2)
ys = fx(xs)
# plt.scatter(xs,ys)
plt.plot(xs,ys)
# Out:
# /tmp/ipykernel_4542/2957431867.py:2: RuntimeWarning: invalid value encountered in divide
#   fx = lambda x: (x**4-16)/(x-2)
