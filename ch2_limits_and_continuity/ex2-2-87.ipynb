# %% [markdown]
# # Ex2.3.87
#
# $ lim_{x\to0} \frac{\sqrt[3]{1+x}-1}{x}$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib.
ticker import MaxNLocator

xs = np.linspace(-0.1,0.1,20)
fx = lambda x: (((1+x)**(1/3))-1)/(x)
ys = fx(xs)
plt.scatter(xs,ys,marker="+")
plt.vlines(x=0, ymin=ys[0], ymax=ys[-1], linestyles="dashed")
plt.grid()
# plt.yticks(np.arange(ys[0],ys[-1],5))
# Ensure ticks are generated within the correct range
# y_min, y_max = ys.min(), ys.max()
# plt.yticks(np.arange(y_min, y_max + 1, 1))  # Adjust step size based on range

ax = plt.gca()  # Get the current axis
ax.xaxis.set_major_locator(MaxNLocator(nbins=10))  # 10 ticks on the x-axis
ax.yaxis.set_major_locator(MaxNLocator(nbins=20))  # 8 ticks on the y-axis

# add limit
fx(xs

# %%
from matplotlib.ticker import MaxNLocator

xs = np.linspace(-0.01,0.01,20)
fx = lambda x: (((1+x)**(1/3))-1)/(x)
ys = fx(xs)
plt.scatter(xs,ys,marker="+")
plt.vlines(x=0, ymin=ys[0], ymax=ys[-1], linestyles="dashed")
ax = plt.gca()  # Get the current axis
ax.xaxis.set_major_locator(MaxNLocator(nbins=10))  # 10 ticks on the x-axis
ax.yaxis.set_major_locator(MaxNLocator(nbins=20))  # 8 ticks on the y-axis
plt.grid()
