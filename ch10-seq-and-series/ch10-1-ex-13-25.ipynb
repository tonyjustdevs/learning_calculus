# %% [raw]
# ---
# title: "Calculus 11: More Sequences"
# author: "Tony Phung"
# date: "2025-01-21"
# categories: [calculus]
# image: "imgs/10-1-ex-13-25.png"
# toc: true
# description: "From Ch10-1 Sequences, Thomas 13e pp.581"
# ---

# %% [markdown]
# ![](imgs/10-1-ex-13-25.png)
